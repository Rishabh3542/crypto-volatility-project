# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("C:\Users\risha\OneDrive\Documents\GitHub\Magic_Repo\crypto-volatility-project\data\dataset.csv")
