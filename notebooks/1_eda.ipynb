# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings
warnings.filterwarnings("ignore")

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\risha\\OneDrive\\Documents\\GitHub\\Magic_Repo\\crypto-volatility-project\\notebooks'

# %%
df = pd.read_csv("../data/dataset.csv")

# %%
df.head()
# Out:
#    Unnamed: 0        open        high         low       close  volume  \
# 0          10  112.799004  122.000000  111.551003  117.199997     0.0
# 1          11    3.406530    3.631640    3.367190    3.443340     0.0
# 2          12  117.699997  118.679001  113.010002  115.242996     0.0
# 3          13    3.460380    3.479810    3.300610    3.348960     0.0
# 4          14    3.362810    3.422240    3.215870    3.269450     0.0
#
#       marketCap                 timestamp crypto_name        date     return  \
# 0  1.305479e+09  2013-05-10T23:59:59.999Z     Bitcoin  2013-05-10   0.040206
# 1  6.035893e+07  2013-05-10T23:59:59.999Z    Litecoin  2013-05-10  -0.970620
# 2  1.284207e+09  2013-05-11T23:59:59.999Z     Bitcoin  2013-05-11  32.468375
# 3  5.880951e+07  2013-05-11T23:59:59.999Z    Litecoin  2013-05-11  -0.970940
# 4  5.751332e+07  2013-05-12T23:59:59.999Z    Litecoin  2013-05-12  -0.023742
#
#    volatility      ma_10  liquidity
# 0   16.690774  58.435627        0.0
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0          open          high           low         close  \
# count  72878.000000  72878.000000  7.287800e+04  72878.000000  7.287800e+04
# mean   36472.730714    870.997730  8.972388e+02    844.840001  8.720984e+02
# std    21061.341891   5234.028478  5.401063e+03   5081.694387  5.237884e+03
# min       10.000000      0.000000  1.022100e-10      0.000000  8.292000e-11
# 25%    18229.250000      0.169104  1.780407e-01      0.160533  1.697003e-01
# 50%    36463.500000      1.643772  1.724625e+00      1.549926  1.648933e+00
# 75%    54725.750000     26.140263  2.760703e+01     24.905990  2.629884e+01
# max    72945.000000  67549.735581  1.621883e+05  66458.723733  6.756683e+04
#
#              volume     marketCap        return    volatility         ma_10  \
# count  7.287800e+04  7.287800e+04  7.287800e+04  7.287800e+04  72878.000000
# mean   2.209667e+09  1.476289e+10  1.465811e+10  4.635184e+10    871.433497
# ...

# %%
plt.figure()
df['close'].plot()
plt.title("Close Price Trend")
plt.show()

# %%
plt.figure()
df[['open','high','low','close']].corr().plot(kind='bar')
plt.show()
