# %%
import pandas as pd

# %%
df = pd.read_csv("../data/dataset.csv")

# %%
df['return'] = df['close'].pct_change()
df['volatility'] = df['return'].rolling(10).std()
df['ma_10'] = df['close'].rolling(10).mean()

# %%
df['liquidity'] = df['volume'] / df['marketCap']

# %%
df = df.dropna()
df.to_csv("D:\crypto-volatility-project\data\dataset.csv", index=False)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\c'
# <>:2: SyntaxWarning: invalid escape sequence '\c'
# C:\Users\risha\AppData\Local\Temp\ipykernel_22996\3980149743.py:2: SyntaxWarning: invalid escape sequence '\c'
#   df.to_csv("D:\crypto-volatility-project\data\dataset.csv", index=False)
